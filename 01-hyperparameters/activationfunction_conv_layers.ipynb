# %%
import cv2
import json
from matplotlib import pyplot as plt
import numpy as np
import os
import random

# import a lot of things from keras:
# sequential model
from keras.models import Sequential

# layers
from keras.layers import Input, Dense, Dropout, Flatten, Conv2D, MaxPooling2D, RandomFlip, RandomRotation, RandomContrast, RandomBrightness

# loss function
from keras.metrics import categorical_crossentropy

# callback functions
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

# convert data to categorial vector representation
from keras.utils import to_categorical

# nice progress bar for loading data
from tqdm.notebook import tqdm

# helper function for train/test split
from sklearn.model_selection import train_test_split

# import confusion matrix helper function
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# import pre-trained model
from keras.applications.vgg16 import VGG16

# include only those gestures
CONDITIONS = ['like', 'stop']

# image size
IMG_SIZE = 64
SIZE = (IMG_SIZE, IMG_SIZE)

# number of color channels we want to use
# set to 1 to convert to grayscale
# set to 3 to use color images
COLOR_CHANNELS = 3

PATH = "../gesture_dataset_sample"

annotations = dict()

for condition in CONDITIONS:
    with open(f'{PATH}/_annotations/{condition}.json') as f:
        annotations[condition] = json.load(f)
        
def preprocess_image(img):
    if COLOR_CHANNELS == 1:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_resized = cv2.resize(img, SIZE)
    return img_resized

images = [] # stores actual image data
labels = [] # stores labels (as integer - because this is what our network needs)
label_names = [] # maps label ints to their actual categories so we can understand predictions later

# loop over all conditions
# loop over all files in the condition's directory
# read the image and corresponding annotation
# crop image to the region of interest
# preprocess image
# store preprocessed image and label in corresponding lists
for condition in CONDITIONS:
    for filename in tqdm(os.listdir(f'{PATH}/{condition}')):
        # extract unique ID from file name
        UID = filename.split('.')[0]
        img = cv2.imread(f'{PATH}/{condition}/{filename}')
        
        # get annotation from the dict we loaded earlier
        try:
            annotation = annotations[condition][UID]
        except Exception as e:
            print(e)
            continue
        
        # iterate over all hands annotated in the image
        for i, bbox in enumerate(annotation['bboxes']):
            # annotated bounding boxes are in the range from 0 to 1
            # therefore we have to scale them to the image size
            x1 = int(bbox[0] * img.shape[1])
            y1 = int(bbox[1] * img.shape[0])
            w = int(bbox[2] * img.shape[1])
            h = int(bbox[3] * img.shape[0])
            x2 = x1 + w
            y2 = y1 + h
            
            # crop image to the bounding box and apply pre-processing
            crop = img[y1:y2, x1:x2]
            preprocessed = preprocess_image(crop)
            
            # get the annotated hand's label
            # if we have not seen this label yet, add it to the list of labels
            label = annotation['labels'][i]
            if label not in label_names:
                label_names.append(label)
            
            label_index = label_names.index(label)
            
            images.append(preprocessed)
            labels.append(label_index)
            
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

print(len(X_train))
print(len(X_test))
print(len(y_train))
print(len(y_test))

X_train = np.array(X_train).astype('float32')
X_train = X_train / 255.

X_test = np.array(X_test).astype('float32')
X_test = X_test / 255.

y_train_one_hot = to_categorical(y_train)
y_test_one_hot = to_categorical(y_test)

train_label = y_train_one_hot
test_label = y_test_one_hot

X_train = X_train.reshape(-1, IMG_SIZE, IMG_SIZE, COLOR_CHANNELS)
X_test = X_test.reshape(-1, IMG_SIZE, IMG_SIZE, COLOR_CHANNELS)

print(X_train.shape, X_test.shape, train_label.shape, test_label.shape)
# Out:
#   0%|          | 0/250 [00:00<?, ?it/s]
#   0%|          | 0/250 [00:00<?, ?it/s]
# 512
# 128
# 512
# 128
# (512, 64, 64, 3) (128, 64, 64, 3) (512, 3) (128, 3)

# %% [markdown]
# 1.Leaky Relu
# training time 12.4s
# 13 epochs

# %%
# 1 leaky_relu 2: elu 3: relu 4: swish 5: linear
# variables for hyperparameters
batch_size = 8
epochs = 50
num_classes = len(label_names)
activation = 'relu'
activation_conv = 'leaky_relu'  # LeakyReLU 
layer_count = 2
num_neurons = 64

# define model structure
# with keras, we can use a model's add() function to add layers to the network one by one
model = Sequential()

# data augmentation (this can also be done beforehand - but don't augment the test dataset!)
model.add(RandomFlip('horizontal'))
model.add(RandomContrast(0.1))
#model.add(RandomBrightness(0.1))
#model.add(RandomRotation(0.2))

# first, we add some convolution layers followed by max pooling
model.add(Conv2D(64, kernel_size=(9, 9), activation=activation_conv, input_shape=(SIZE[0], SIZE[1], COLOR_CHANNELS), padding='same'))
model.add(MaxPooling2D(pool_size=(4, 4), padding='same'))

model.add(Conv2D(32, (5, 5), activation=activation_conv, padding='same'))
model.add(MaxPooling2D(pool_size=(3, 3), padding='same'))

model.add(Conv2D(32, (3, 3), activation=activation_conv, padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))

# dropout layers can drop part of the data during each epoch - this prevents overfitting
model.add(Dropout(0.2))

# after the convolution layers, we have to flatten the data so it can be fed into fully connected layers
model.add(Flatten())

# add some fully connected layers ("Dense")
for i in range(layer_count - 1):
    model.add(Dense(num_neurons, activation=activation))

model.add(Dense(num_neurons, activation=activation))

# for classification, the last layer has to use the softmax activation function, which gives us probabilities for each category
model.add(Dense(num_classes, activation='softmax'))

# specify loss function, optimizer and evaluation metrics
# for classification, categorial crossentropy is used as a loss function
# use the adam optimizer unless you have a good reason not to
model.compile(loss=categorical_crossentropy, optimizer="adam", metrics=['accuracy'])

# define callback functions that react to the model's behavior during training
# in this example, we reduce the learning rate once we get stuck and early stopping
# to cancel the training if there are no improvements for a certain amount of epochs
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.0001)
stop_early = EarlyStopping(monitor='val_loss', patience=3)

history = model.fit(
    X_train,
    train_label,
    batch_size=batch_size,
    epochs=epochs,
    verbose=1,
    validation_data=(X_test, test_label),
    callbacks=[reduce_lr, stop_early]
)

model.summary()

loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

fig = plt.figure(figsize=(15, 7))
ax = plt.gca()

ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy (Line), Loss (Dashes)')

ax.axhline(1, color='gray')

plt.plot(accuracy, color='blue')
plt.plot(val_accuracy, color='orange')
plt.plot(loss, '--', color='blue', alpha=0.5)
plt.plot(val_loss, '--', color='orange', alpha=0.5)

model.save('gesture_recognition_1.keras')

# let the model make predictions for our training data
y_predictions = model.predict(X_test)

# we get a 2D numpy array with probabilities for each category
print('before', y_predictions)

# to build a confusion matrix, we have to convert it to classifications
# this can be done by using the argmax() function to set the probability to 1 and the rest to 0
y_predictions = np.argmax(y_predictions, axis=1)

print('probabilities', y_predictions)

# create and plot confusion matrix
conf_matrix = confusion_matrix(y_test, y_predictions)

fig = plt.figure(figsize=(10, 10))

ConfusionMatrixDisplay(conf_matrix, display_labels=label_names).plot(ax=plt.gca())

plt.xticks(rotation=90, ha='center')
pass
# Out:
# Epoch 1/50
# C:\pythonstuff\assignment-5-cnn-johnnyklein\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.4168 - loss: 1.0751 - val_accuracy: 0.4062 - val_loss: 1.0332 - learning_rate: 0.0010
# Epoch 2/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4579 - loss: 1.0209 - val_accuracy: 0.5625 - val_loss: 0.9505 - learning_rate: 0.0010
# Epoch 3/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5456 - loss: 0.9381 - val_accuracy: 0.6406 - val_loss: 0.8674 - learning_rate: 0.0010
# Epoch 4/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7145 - loss: 0.7027 - val_accuracy: 0.8281 - val_loss: 0.4398 - learning_rate: 0.0010
# Epoch 5/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7938 - loss: 0.5382 - val_accuracy: 0.8906 - val_loss: 0.3182 - learning_rate: 0.0010
# Epoch 6/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9036 - loss: 0.2758 - val_accuracy: 0.9141 - val_loss: 0.2713 - learning_rate: 0.0010
# Epoch 7/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8799 - loss: 0.3650 - val_accuracy: 0.9297 - val_loss: 0.2282 - learning_rate: 0.0010
# Epoch 8/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9395 - loss: 0.1652 - val_accuracy: 0.8672 - val_loss: 0.4037 - learning_rate: 0.0010
# Epoch 9/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9293 - loss: 0.2004 - val_accuracy: 0.9141 - val_loss: 0.3298 - learning_rate: 0.0010
# Epoch 10/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9530 - loss: 0.1196 - val_accuracy: 0.9609 - val_loss: 0.1847 - learning_rate: 2.0000e-04
# Epoch 11/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9743 - loss: 0.0802 - val_accuracy: 0.9453 - val_loss: 0.1996 - learning_rate: 2.0000e-04
# Epoch 12/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9666 - loss: 0.0860 - val_accuracy: 0.9453 - val_loss: 0.2258 - learning_rate: 2.0000e-04
# Epoch 13/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9616 - loss: 0.0980 - val_accuracy: 0.9453 - val_loss: 0.1877 - learning_rate: 1.0000e-04
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip_6 (RandomFlip)      │ (8, 64, 64, 3)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_contrast_6               │ (8, 64, 64, 3)         │             0 │
# │ (RandomContrast)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_18 (Conv2D)              │ (8, 64, 64, 64)        │        15,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_18 (MaxPooling2D) │ (8, 16, 16, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (8, 16, 16, 32)        │        51,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_19 (MaxPooling2D) │ (8, 6, 6, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (8, 6, 6, 32)          │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_20 (MaxPooling2D) │ (8, 3, 3, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (8, 3, 3, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (8, 288)               │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (8, 64)                │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (8, 64)                │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (8, 3)                 │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 296,843 (1.13 MB)
#  Trainable params: 98,947 (386.51 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 197,896 (773.04 KB)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# before [[1.29120573e-01 5.00549853e-04 8.70378852e-01]
#  [9.99296069e-01 5.67947747e-04 1.35872484e-04]
#  [9.97310996e-01 8.77664570e-05 2.60126544e-03]
#  [6.30969706e-04 6.21162253e-05 9.99306917e-01]
#  [9.99769390e-01 3.16367950e-05 1.99049449e-04]
#  [9.99998093e-01 1.77374511e-06 1.21031206e-07]
#  [9.99956250e-01 1.15497386e-07 4.36105074e-05]
#  [9.31124985e-02 9.06662583e-01 2.24900738e-04]
#  [9.99908209e-01 1.63303375e-05 7.54859502e-05]
#  [9.98579502e-01 1.69225881e-04 1.25127425e-03]
#  [1.31516147e-03 6.87040389e-04 9.97997701e-01]
#  [1.59356292e-04 9.99837399e-01 3.18838556e-06]
#  [8.39309692e-01 1.26528203e-01 3.41621228e-02]
#  [2.92761135e-03 1.33235147e-03 9.95740056e-01]
#  [1.00000000e+00 4.98879587e-08 1.09992442e-08]
#  [3.48959956e-03 3.30096832e-03 9.93209422e-01]
#  [2.79726628e-05 9.99971986e-01 8.01290412e-08]
#  [7.50431500e-05 2.14833944e-05 9.99903440e-01]
#  [9.03314445e-03 9.88915443e-01 2.05142540e-03]
#  [4.83131123e-04 2.30607257e-05 9.99493718e-01]
#  [6.12205386e-01 2.71051049e-01 1.16743557e-01]
#  [1.55460311e-03 1.32807370e-04 9.98312593e-01]
#  [2.59881526e-01 7.12886512e-01 2.72319987e-02]
#  [4.25252474e-05 7.09719961e-06 9.99950290e-01]
#  [9.94851768e-01 1.57820701e-03 3.57011706e-03]
#  [5.82765555e-04 3.33307617e-06 9.99413967e-01]
#  [1.36608968e-03 5.81778913e-05 9.98575687e-01]
#  [2.80529121e-03 4.69729966e-05 9.97147739e-01]
#  [9.83816504e-01 1.59186004e-06 1.61818638e-02]
#  [2.18703598e-02 5.64219314e-04 9.77565408e-01]
#  [2.27982085e-03 8.98558937e-04 9.96821523e-01]
#  [4.94224543e-04 3.28594979e-05 9.99472916e-01]
#  [9.98655081e-01 2.82440102e-04 1.06255536e-03]
#  [9.94307458e-01 9.31277827e-05 5.59934648e-03]
#  [9.99993801e-01 7.20275295e-07 5.44242994e-06]
#  [9.99947071e-01 5.28800629e-05 1.00466515e-08]
#  [9.99950647e-01 4.06809595e-05 8.71533302e-06]
#  [9.99788582e-01 1.50596088e-05 1.96418725e-04]
#  [2.26329989e-03 9.97663021e-01 7.37301380e-05]
#  [4.25789971e-03 9.94701505e-01 1.04058220e-03]
#  [1.81454886e-02 9.78018701e-01 3.83582455e-03]
#  [8.64156405e-04 4.61680320e-05 9.99089599e-01]
#  [9.90453839e-01 4.61771060e-03 4.92843846e-03]
#  [2.23896815e-03 9.97594178e-01 1.66785074e-04]
#  [7.27669150e-03 9.91645634e-01 1.07766944e-03]
#  [9.98291552e-01 4.16294264e-04 1.29214895e-03]
#  [2.87383068e-02 1.38775017e-02 9.57384169e-01]
#  [9.99790967e-01 1.99501992e-05 1.89176630e-04]
#  [1.82524353e-01 4.13578041e-02 7.76117802e-01]
#  [9.99990821e-01 5.56394798e-06 3.54804160e-06]
#  [5.51088760e-03 3.86556203e-04 9.94102538e-01]
#  [2.68884778e-01 8.26781690e-02 6.48437083e-01]
#  [1.78368049e-04 3.92780476e-06 9.99817669e-01]
#  [8.75630438e-01 1.33783312e-03 1.23031631e-01]
#  [9.99987245e-01 4.82449764e-07 1.22553174e-05]
#  [9.90064919e-01 6.96424919e-04 9.23864637e-03]
#  [9.60479856e-01 5.47530304e-04 3.89726646e-02]
#  [1.14557906e-05 2.60540503e-07 9.99988317e-01]
#  [9.99919772e-01 1.45173590e-05 6.57004639e-05]
#  [3.46225381e-01 2.46954197e-03 6.51305079e-01]
#  [3.98886902e-03 9.95235980e-01 7.75144435e-04]
#  [9.91658151e-01 7.23268371e-03 1.10903941e-03]
#  [2.03232486e-02 6.62892265e-03 9.73047793e-01]
#  [9.77262497e-01 2.25936174e-02 1.43906043e-04]
#  [4.17538657e-04 2.92795521e-05 9.99553144e-01]
#  [1.67717854e-03 1.04745915e-04 9.98218119e-01]
#  [1.47129502e-02 9.84233916e-01 1.05313736e-03]
#  [1.98315471e-01 8.64022784e-03 7.93044329e-01]
#  [1.43779663e-03 9.96605277e-01 1.95691339e-03]
#  [9.97048438e-01 1.29956019e-03 1.65201281e-03]
#  [3.53820302e-04 6.99066459e-06 9.99639153e-01]
#  [9.99923229e-01 1.52474795e-05 6.14994569e-05]
#  [9.99997139e-01 2.23984080e-06 5.82492021e-07]
#  [9.99940872e-01 3.11317563e-05 2.80557069e-05]
#  [9.86275315e-01 1.01240976e-02 3.60059342e-03]
#  [1.84481105e-05 9.99981284e-01 2.09186851e-07]
#  [9.99798954e-01 1.58836028e-05 1.85236073e-04]
#  [7.06982319e-05 1.35437964e-04 9.99793947e-01]
#  [2.46140175e-04 3.70930247e-05 9.99716818e-01]
#  [9.99995232e-01 2.19005216e-07 4.51682990e-06]
#  [9.99844432e-01 1.45533093e-04 1.00184261e-05]
#  [9.62228049e-04 5.11334256e-05 9.98986661e-01]
#  [1.03340193e-04 9.99575198e-01 3.21432133e-04]
#  [9.99866843e-01 1.01596070e-05 1.22971644e-04]
#  [4.09361703e-04 3.24822322e-05 9.99558151e-01]
#  [9.98415589e-01 1.48761563e-03 9.68099848e-05]
#  [9.99220371e-01 6.34409080e-04 1.45234080e-04]
#  [1.45323612e-02 9.77834463e-01 7.63317430e-03]
#  [9.99998689e-01 1.12098166e-06 2.16274330e-07]
#  [5.94958197e-03 1.36290808e-04 9.93914187e-01]
#  [9.25390065e-01 2.15937756e-03 7.24505335e-02]
#  [9.08878352e-03 7.60485651e-04 9.90150690e-01]
#  [9.89129305e-01 9.34507605e-03 1.52559939e-03]
#  [1.33656245e-03 3.54518488e-05 9.98628020e-01]
#  [2.48013493e-02 9.74939525e-01 2.59055727e-04]
#  [9.99994278e-01 5.56194573e-06 1.66022716e-07]
#  [9.16970134e-01 3.26742535e-03 7.97624663e-02]
#  [6.07698783e-03 8.87031318e-04 9.93035972e-01]
#  [3.45355329e-05 9.99964356e-01 1.06014056e-06]
#  [9.86045182e-01 1.11244889e-02 2.83031748e-03]
#  [7.53772561e-04 9.99160409e-01 8.58596468e-05]
#  [1.75539299e-03 1.96122695e-04 9.98048544e-01]
#  [7.29277555e-04 9.99247432e-01 2.33370902e-05]
#  [4.70902445e-03 1.06030330e-03 9.94230747e-01]
#  [2.91045981e-05 5.05764206e-07 9.99970436e-01]
#  [9.99999285e-01 2.05041431e-07 4.44470317e-07]
#  [2.49193292e-02 6.25836058e-03 9.68822300e-01]
#  [9.99999642e-01 3.37316237e-07 4.41825493e-10]
#  [9.99917150e-01 7.82720381e-05 4.56417547e-06]
#  [9.98433053e-01 1.24887959e-03 3.17972037e-04]
#  [2.12393075e-04 9.99785841e-01 1.74840613e-06]
#  [2.82108784e-03 9.96887147e-01 2.91795906e-04]
#  [9.78103280e-01 1.61779132e-02 5.71886124e-03]
#  [1.26330951e-05 1.91374113e-07 9.99987125e-01]
#  [3.00018559e-03 9.96980846e-01 1.89824877e-05]
#  [1.13412462e-01 4.18398269e-02 8.44747782e-01]
#  [6.51808514e-05 2.25024360e-05 9.99912262e-01]
#  [9.99990225e-01 3.85044950e-06 5.90739910e-06]
#  [9.63359177e-01 1.08883716e-04 3.65319587e-02]
#  [1.35477027e-03 1.94448512e-03 9.96700704e-01]
#  [1.22798551e-02 9.83585596e-01 4.13453253e-03]
#  [1.23695924e-03 2.08594676e-04 9.98554528e-01]
#  [1.94055866e-02 9.79337573e-01 1.25681097e-03]
#  [3.68269235e-02 6.67937973e-04 9.62505162e-01]
#  [9.99978065e-01 3.41216560e-06 1.84214859e-05]
#  [3.15148733e-03 4.43403125e-02 9.52508152e-01]
#  [8.82116780e-02 4.37901675e-04 9.11350429e-01]
#  [3.60201811e-05 2.31289869e-06 9.99961734e-01]]
# probabilities [2 0 0 2 0 0 0 1 0 0 2 1 0 2 0 2 1 2 1 2 0 2 1 2 0 2 2 2 0 2 2 2 0 0 0 0 0
#  0 1 1 1 2 0 1 1 0 2 0 2 0 2 2 2 0 0 0 0 2 0 2 1 0 2 0 2 2 1 2 1 0 2 0 0 0
#  0 1 0 2 2 0 0 2 1 0 2 0 0 1 0 2 0 2 0 2 1 0 0 2 1 0 1 2 1 2 2 0 2 0 0 0 1
#  1 0 2 1 2 2 0 0 2 1 2 1 2 0 2 2 2]

# %% [markdown]
# 2. Elu
# training time 15.2s

# %%
# 1 leaky_relu 2: elu 3: relu 4: swish 5: linear
# variables for hyperparameters
batch_size = 8
epochs = 50
num_classes = len(label_names)
activation = 'relu'
activation_conv = 'elu'  
layer_count = 2
num_neurons = 64

# define model structure
# with keras, we can use a model's add() function to add layers to the network one by one
model = Sequential()

# data augmentation (this can also be done beforehand - but don't augment the test dataset!)
model.add(RandomFlip('horizontal'))
model.add(RandomContrast(0.1))
#model.add(RandomBrightness(0.1))
#model.add(RandomRotation(0.2))

# first, we add some convolution layers followed by max pooling
model.add(Conv2D(64, kernel_size=(9, 9), activation=activation_conv, input_shape=(SIZE[0], SIZE[1], COLOR_CHANNELS), padding='same'))
model.add(MaxPooling2D(pool_size=(4, 4), padding='same'))

model.add(Conv2D(32, (5, 5), activation=activation_conv, padding='same'))
model.add(MaxPooling2D(pool_size=(3, 3), padding='same'))

model.add(Conv2D(32, (3, 3), activation=activation_conv, padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))

# dropout layers can drop part of the data during each epoch - this prevents overfitting
model.add(Dropout(0.2))

# after the convolution layers, we have to flatten the data so it can be fed into fully connected layers
model.add(Flatten())

# add some fully connected layers ("Dense")
for i in range(layer_count - 1):
    model.add(Dense(num_neurons, activation=activation))

model.add(Dense(num_neurons, activation=activation))

# for classification, the last layer has to use the softmax activation function, which gives us probabilities for each category
model.add(Dense(num_classes, activation='softmax'))

# specify loss function, optimizer and evaluation metrics
# for classification, categorial crossentropy is used as a loss function
# use the adam optimizer unless you have a good reason not to
model.compile(loss=categorical_crossentropy, optimizer="adam", metrics=['accuracy'])

# define callback functions that react to the model's behavior during training
# in this example, we reduce the learning rate once we get stuck and early stopping
# to cancel the training if there are no improvements for a certain amount of epochs
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.0001)
stop_early = EarlyStopping(monitor='val_loss', patience=3)

history = model.fit(
    X_train,
    train_label,
    batch_size=batch_size,
    epochs=epochs,
    verbose=1,
    validation_data=(X_test, test_label),
    callbacks=[reduce_lr, stop_early]
)

model.summary()

loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

fig = plt.figure(figsize=(15, 7))
ax = plt.gca()

ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy (Line), Loss (Dashes)')

ax.axhline(1, color='gray')

plt.plot(accuracy, color='blue')
plt.plot(val_accuracy, color='orange')
plt.plot(loss, '--', color='blue', alpha=0.5)
plt.plot(val_loss, '--', color='orange', alpha=0.5)

model.save('gesture_recognition_2.keras')

# let the model make predictions for our training data
y_predictions = model.predict(X_test)

# we get a 2D numpy array with probabilities for each category
print('before', y_predictions)

# to build a confusion matrix, we have to convert it to classifications
# this can be done by using the argmax() function to set the probability to 1 and the rest to 0
y_predictions = np.argmax(y_predictions, axis=1)

print('probabilities', y_predictions)

# create and plot confusion matrix
conf_matrix = confusion_matrix(y_test, y_predictions)

fig = plt.figure(figsize=(10, 10))

ConfusionMatrixDisplay(conf_matrix, display_labels=label_names).plot(ax=plt.gca())

plt.xticks(rotation=90, ha='center')
pass
# Out:
# Epoch 1/50
# C:\pythonstuff\assignment-5-cnn-johnnyklein\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.3783 - loss: 1.1710 - val_accuracy: 0.3516 - val_loss: 1.0943 - learning_rate: 0.0010
# Epoch 2/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4271 - loss: 1.0630 - val_accuracy: 0.4219 - val_loss: 1.0752 - learning_rate: 0.0010
# Epoch 3/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4754 - loss: 1.0311 - val_accuracy: 0.5391 - val_loss: 1.0456 - learning_rate: 0.0010
# Epoch 4/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5383 - loss: 0.9978 - val_accuracy: 0.5938 - val_loss: 0.9568 - learning_rate: 0.0010
# Epoch 5/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5977 - loss: 0.9380 - val_accuracy: 0.6641 - val_loss: 0.7032 - learning_rate: 0.0010
# Epoch 6/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7212 - loss: 0.6957 - val_accuracy: 0.7734 - val_loss: 0.5162 - learning_rate: 0.0010
# Epoch 7/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8801 - loss: 0.3987 - val_accuracy: 0.8516 - val_loss: 0.3744 - learning_rate: 0.0010
# Epoch 8/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8814 - loss: 0.3055 - val_accuracy: 0.9141 - val_loss: 0.2576 - learning_rate: 0.0010
# Epoch 9/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8967 - loss: 0.2970 - val_accuracy: 0.8906 - val_loss: 0.3158 - learning_rate: 0.0010
# Epoch 10/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9063 - loss: 0.2700 - val_accuracy: 0.9062 - val_loss: 0.2890 - learning_rate: 0.0010
# Epoch 11/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9421 - loss: 0.1709 - val_accuracy: 0.9219 - val_loss: 0.1981 - learning_rate: 2.0000e-04
# Epoch 12/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9586 - loss: 0.1538 - val_accuracy: 0.9453 - val_loss: 0.1773 - learning_rate: 2.0000e-04
# Epoch 13/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9757 - loss: 0.0816 - val_accuracy: 0.9453 - val_loss: 0.1778 - learning_rate: 2.0000e-04
# Epoch 14/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9862 - loss: 0.0534 - val_accuracy: 0.9531 - val_loss: 0.1717 - learning_rate: 2.0000e-04
# Epoch 15/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9836 - loss: 0.0857 - val_accuracy: 0.9531 - val_loss: 0.1761 - learning_rate: 2.0000e-04
# Epoch 16/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9831 - loss: 0.0661 - val_accuracy: 0.9531 - val_loss: 0.1859 - learning_rate: 2.0000e-04
# Epoch 17/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9886 - loss: 0.0535 - val_accuracy: 0.9453 - val_loss: 0.1760 - learning_rate: 1.0000e-04
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip_7 (RandomFlip)      │ (8, 64, 64, 3)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_contrast_7               │ (8, 64, 64, 3)         │             0 │
# │ (RandomContrast)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)              │ (8, 64, 64, 64)        │        15,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_21 (MaxPooling2D) │ (8, 16, 16, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_22 (Conv2D)              │ (8, 16, 16, 32)        │        51,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_22 (MaxPooling2D) │ (8, 6, 6, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_23 (Conv2D)              │ (8, 6, 6, 32)          │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_23 (MaxPooling2D) │ (8, 3, 3, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (8, 3, 3, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_7 (Flatten)             │ (8, 288)               │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (8, 64)                │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (8, 64)                │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (8, 3)                 │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 296,843 (1.13 MB)
#  Trainable params: 98,947 (386.51 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 197,896 (773.04 KB)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# before [[9.41356421e-02 8.46158364e-04 9.05018151e-01]
#  [9.99656558e-01 3.15536105e-04 2.79048563e-05]
#  [9.99347866e-01 1.06938744e-04 5.45203744e-04]
#  [1.17652817e-04 5.47002583e-06 9.99876857e-01]
#  [9.99602973e-01 2.73215090e-04 1.23867256e-04]
#  [9.99966741e-01 3.30180665e-05 2.87230563e-07]
#  [9.99892592e-01 6.34097960e-05 4.40426484e-05]
#  [1.07894056e-01 8.91569674e-01 5.36263164e-04]
#  [9.99489069e-01 4.57738643e-04 5.31530677e-05]
#  [9.99510169e-01 2.55781371e-04 2.34030624e-04]
#  [1.95784902e-04 7.83920113e-04 9.99020338e-01]
#  [1.47702158e-05 9.99977350e-01 7.84980602e-06]
#  [6.31215870e-01 3.51564169e-01 1.72199756e-02]
#  [6.87445281e-04 1.68869141e-04 9.99143600e-01]
#  [9.99982476e-01 1.72024047e-05 3.28692920e-07]
#  [8.62868386e-04 1.78537727e-03 9.97351766e-01]
#  [1.17322488e-05 9.99987721e-01 5.75726745e-07]
#  [9.34412004e-04 1.16505689e-05 9.99053895e-01]
#  [4.90237586e-03 9.87715304e-01 7.38224993e-03]
#  [6.20726714e-05 6.90037814e-06 9.99930978e-01]
#  [3.93056184e-01 5.70905805e-01 3.60379592e-02]
#  [6.15273379e-02 2.32301862e-03 9.36149716e-01]
#  [1.38991803e-01 8.47526014e-01 1.34822018e-02]
#  [5.36503794e-04 3.50004439e-06 9.99460042e-01]
#  [9.93669569e-01 3.51294526e-03 2.81760073e-03]
#  [8.64062400e-04 1.24878788e-05 9.99123394e-01]
#  [1.08038868e-04 3.40396691e-05 9.99857903e-01]
#  [2.40336335e-03 6.53663010e-05 9.97531235e-01]
#  [9.91816819e-01 4.67219390e-04 7.71589857e-03]
#  [5.84013900e-03 1.37792237e-03 9.92781878e-01]
#  [1.00512430e-03 7.62179960e-04 9.98232603e-01]
#  [5.82436391e-04 2.26798838e-05 9.99394894e-01]
#  [9.98227894e-01 4.73507913e-04 1.29861815e-03]
#  [9.94053304e-01 1.00033218e-03 4.94631613e-03]
#  [9.99922156e-01 5.61456691e-05 2.17005654e-05]
#  [9.51722503e-01 4.82739247e-02 3.53234645e-06]
#  [9.99643683e-01 3.29908071e-04 2.65090930e-05]
#  [9.97640610e-01 8.33029335e-04 1.52647006e-03]
#  [2.24518287e-03 9.97616053e-01 1.38793373e-04]
#  [1.48921320e-03 9.97019708e-01 1.49109261e-03]
#  [3.03545371e-02 9.44763184e-01 2.48823389e-02]
#  [6.09850604e-03 2.84043839e-04 9.93617415e-01]
#  [9.76720154e-01 1.59477647e-02 7.33203348e-03]
#  [1.63057470e-04 9.99813974e-01 2.29790821e-05]
#  [3.71204136e-04 9.99416947e-01 2.11850318e-04]
#  [9.97506917e-01 2.31176568e-03 1.81284209e-04]
#  [2.61155754e-01 1.25258148e-01 6.13586128e-01]
#  [9.99926805e-01 5.24046773e-05 2.07852336e-05]
#  [1.11807235e-01 4.48001437e-02 8.43392670e-01]
#  [9.99941707e-01 5.19451969e-05 6.30909972e-06]
#  [3.62747698e-03 3.08381417e-03 9.93288696e-01]
#  [2.58484304e-01 6.41939580e-01 9.95760933e-02]
#  [4.22597695e-05 2.29833677e-06 9.99955416e-01]
#  [9.01688874e-01 1.06417509e-02 8.76693204e-02]
#  [9.99960303e-01 2.90660810e-05 1.05972340e-05]
#  [9.43473518e-01 1.43172229e-02 4.22092937e-02]
#  [9.49447215e-01 1.23813301e-02 3.81714627e-02]
#  [4.45191154e-06 3.82956699e-07 9.99995232e-01]
#  [9.99159455e-01 8.00331589e-04 4.02119949e-05]
#  [4.69270140e-01 3.51640559e-03 5.27213514e-01]
#  [5.21587033e-04 9.99369204e-01 1.09173976e-04]
#  [9.89547372e-01 9.97087918e-03 4.81718249e-04]
#  [4.72516473e-03 6.86124712e-03 9.88413632e-01]
#  [9.57764685e-01 4.15091887e-02 7.26188067e-04]
#  [3.59114201e-05 2.61112691e-05 9.99938011e-01]
#  [2.19477643e-03 1.56670838e-04 9.97648537e-01]
#  [7.62496702e-03 9.91101265e-01 1.27376302e-03]
#  [2.61962056e-01 5.01964428e-02 6.87841535e-01]
#  [1.80039392e-03 9.94554162e-01 3.64541006e-03]
#  [9.92733002e-01 5.54721244e-03 1.71976676e-03]
#  [3.31256015e-04 1.58008144e-04 9.99510765e-01]
#  [9.99821961e-01 1.25048915e-04 5.30773505e-05]
#  [9.99901891e-01 9.58048258e-05 2.25163967e-06]
#  [9.99892473e-01 1.04866085e-04 2.57696297e-06]
#  [9.59139347e-01 3.04483473e-02 1.04122767e-02]
#  [1.54637790e-03 9.97508287e-01 9.45346314e-04]
#  [9.99726713e-01 2.44717870e-04 2.85941751e-05]
#  [3.16171645e-05 2.59968190e-04 9.99708474e-01]
#  [3.92998772e-05 1.24494636e-05 9.99948263e-01]
#  [9.99715149e-01 1.58458206e-04 1.26326166e-04]
#  [9.99894023e-01 9.95262599e-05 6.39517430e-06]
#  [4.07155574e-04 3.58130383e-05 9.99556959e-01]
#  [6.96844421e-04 9.96426404e-01 2.87674740e-03]
#  [9.99975085e-01 1.51444319e-05 9.80313416e-06]
#  [9.59331228e-05 3.48876143e-04 9.99555171e-01]
#  [9.93733704e-01 5.89488307e-03 3.71321046e-04]
#  [9.92848277e-01 5.20109385e-03 1.95069099e-03]
#  [4.78261104e-03 9.94052589e-01 1.16479758e-03]
#  [9.99942541e-01 5.62928581e-05 1.17645720e-06]
#  [8.22819211e-03 4.04053484e-04 9.91367757e-01]
#  [9.29526031e-01 7.88135454e-03 6.25926256e-02]
#  [3.81688424e-03 3.43596854e-04 9.95839596e-01]
#  [9.89547849e-01 9.57268663e-03 8.79428524e-04]
#  [2.19549634e-03 3.99777200e-05 9.97764587e-01]
#  [4.97390376e-03 9.94763613e-01 2.62440415e-04]
#  [9.99335349e-01 6.60831574e-04 3.82724602e-06]
#  [9.75038826e-01 6.81751501e-03 1.81435812e-02]
#  [3.27912765e-03 1.15481939e-03 9.95566070e-01]
#  [1.22645042e-05 9.99984145e-01 3.53998394e-06]
#  [9.84750628e-01 1.35442074e-02 1.70528621e-03]
#  [6.13120268e-04 9.99143839e-01 2.43026254e-04]
#  [1.44369563e-03 8.56988918e-05 9.98470604e-01]
#  [1.24842336e-04 9.99848008e-01 2.71831777e-05]
#  [4.81332233e-03 1.63961740e-04 9.95022774e-01]
#  [1.40199132e-04 9.34522268e-06 9.99850512e-01]
#  [9.99991298e-01 8.61201079e-06 1.16131893e-07]
#  [3.33757576e-04 7.17789109e-04 9.98948395e-01]
#  [9.99998093e-01 1.88891454e-06 1.57269842e-08]
#  [9.98781621e-01 1.20999780e-03 8.35921765e-06]
#  [9.92363811e-01 6.97354646e-03 6.62688166e-04]
#  [1.86147125e-04 9.99808133e-01 5.71147984e-06]
#  [4.22794634e-04 9.99523163e-01 5.40028668e-05]
#  [8.31691682e-01 1.40801534e-01 2.75067464e-02]
#  [1.05715160e-04 3.85788280e-06 9.99890447e-01]
#  [4.56858566e-03 9.95328069e-01 1.03364066e-04]
#  [7.58153796e-02 5.48927128e-01 3.75257492e-01]
#  [7.05596030e-05 9.77189302e-06 9.99919653e-01]
#  [9.99829531e-01 1.66325553e-04 4.14383339e-06]
#  [9.95807528e-01 4.52964479e-04 3.73951509e-03]
#  [1.78492934e-04 8.48394877e-04 9.98973131e-01]
#  [1.70643907e-02 9.80008364e-01 2.92729517e-03]
#  [1.67103019e-04 9.77220843e-05 9.99735177e-01]
#  [5.13116159e-02 9.47851181e-01 8.37261381e-04]
#  [1.16657717e-02 2.04373791e-04 9.88129854e-01]
#  [9.99796331e-01 1.95405533e-04 8.21807316e-06]
#  [1.46140388e-04 2.26747096e-02 9.77179110e-01]
#  [1.42297670e-01 6.97406754e-03 8.50728214e-01]
#  [1.54278732e-05 4.51814012e-05 9.99939442e-01]]
# probabilities [2 0 0 2 0 0 0 1 0 0 2 1 0 2 0 2 1 2 1 2 1 2 1 2 0 2 2 2 0 2 2 2 0 0 0 0 0
#  0 1 1 1 2 0 1 1 0 2 0 2 0 2 1 2 0 0 0 0 2 0 2 1 0 2 0 2 2 1 2 1 0 2 0 0 0
#  0 1 0 2 2 0 0 2 1 0 2 0 0 1 0 2 0 2 0 2 1 0 0 2 1 0 1 2 1 2 2 0 2 0 0 0 1
#  1 0 2 1 1 2 0 0 2 1 2 1 2 0 2 2 2]

# %% [markdown]
# 3. relu
# training time 18.2s

# %%
# variables for hyperparameters
batch_size = 8
epochs = 50
num_classes = len(label_names)
activation = 'relu'
activation_conv = 'relu'  # LeakyReLU 
layer_count = 2
num_neurons = 64

# define model structure
# with keras, we can use a model's add() function to add layers to the network one by one
model = Sequential()

# data augmentation (this can also be done beforehand - but don't augment the test dataset!)
model.add(RandomFlip('horizontal'))
model.add(RandomContrast(0.1))
#model.add(RandomBrightness(0.1))
#model.add(RandomRotation(0.2))

# first, we add some convolution layers followed by max pooling
model.add(Conv2D(64, kernel_size=(9, 9), activation=activation_conv, input_shape=(SIZE[0], SIZE[1], COLOR_CHANNELS), padding='same'))
model.add(MaxPooling2D(pool_size=(4, 4), padding='same'))

model.add(Conv2D(32, (5, 5), activation=activation_conv, padding='same'))
model.add(MaxPooling2D(pool_size=(3, 3), padding='same'))

model.add(Conv2D(32, (3, 3), activation=activation_conv, padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))

# dropout layers can drop part of the data during each epoch - this prevents overfitting
model.add(Dropout(0.2))

# after the convolution layers, we have to flatten the data so it can be fed into fully connected layers
model.add(Flatten())

# add some fully connected layers ("Dense")
for i in range(layer_count - 1):
    model.add(Dense(num_neurons, activation=activation))

model.add(Dense(num_neurons, activation=activation))

# for classification, the last layer has to use the softmax activation function, which gives us probabilities for each category
model.add(Dense(num_classes, activation='softmax'))

# specify loss function, optimizer and evaluation metrics
# for classification, categorial crossentropy is used as a loss function
# use the adam optimizer unless you have a good reason not to
model.compile(loss=categorical_crossentropy, optimizer="adam", metrics=['accuracy'])

# define callback functions that react to the model's behavior during training
# in this example, we reduce the learning rate once we get stuck and early stopping
# to cancel the training if there are no improvements for a certain amount of epochs
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.0001)
stop_early = EarlyStopping(monitor='val_loss', patience=3)

history = model.fit(
    X_train,
    train_label,
    batch_size=batch_size,
    epochs=epochs,
    verbose=1,
    validation_data=(X_test, test_label),
    callbacks=[reduce_lr, stop_early]
)

model.summary()

loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

fig = plt.figure(figsize=(15, 7))
ax = plt.gca()

ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy (Line), Loss (Dashes)')

ax.axhline(1, color='gray')

plt.plot(accuracy, color='blue')
plt.plot(val_accuracy, color='orange')
plt.plot(loss, '--', color='blue', alpha=0.5)
plt.plot(val_loss, '--', color='orange', alpha=0.5)

model.save('gesture_recognition_3.keras')

# let the model make predictions for our training data
y_predictions = model.predict(X_test)

# we get a 2D numpy array with probabilities for each category
print('before', y_predictions)

# to build a confusion matrix, we have to convert it to classifications
# this can be done by using the argmax() function to set the probability to 1 and the rest to 0
y_predictions = np.argmax(y_predictions, axis=1)

print('probabilities', y_predictions)

# create and plot confusion matrix
conf_matrix = confusion_matrix(y_test, y_predictions)

fig = plt.figure(figsize=(10, 10))

ConfusionMatrixDisplay(conf_matrix, display_labels=label_names).plot(ax=plt.gca())

plt.xticks(rotation=90, ha='center')
pass
# Out:
# Epoch 1/50
# C:\pythonstuff\assignment-5-cnn-johnnyklein\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.3735 - loss: 1.0850 - val_accuracy: 0.3672 - val_loss: 1.0720 - learning_rate: 0.0010
# Epoch 2/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4163 - loss: 1.0325 - val_accuracy: 0.6250 - val_loss: 0.8394 - learning_rate: 0.0010
# Epoch 3/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6220 - loss: 0.8224 - val_accuracy: 0.6875 - val_loss: 0.6596 - learning_rate: 0.0010
# Epoch 4/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7268 - loss: 0.6613 - val_accuracy: 0.7266 - val_loss: 0.6112 - learning_rate: 0.0010
# Epoch 5/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7668 - loss: 0.5298 - val_accuracy: 0.8203 - val_loss: 0.4542 - learning_rate: 0.0010
# Epoch 6/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8311 - loss: 0.4718 - val_accuracy: 0.8203 - val_loss: 0.4753 - learning_rate: 0.0010
# Epoch 7/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8602 - loss: 0.3484 - val_accuracy: 0.8281 - val_loss: 0.4054 - learning_rate: 0.0010
# Epoch 8/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8706 - loss: 0.3647 - val_accuracy: 0.8672 - val_loss: 0.3885 - learning_rate: 0.0010
# Epoch 9/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8783 - loss: 0.3438 - val_accuracy: 0.8281 - val_loss: 0.4003 - learning_rate: 0.0010
# Epoch 10/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9110 - loss: 0.2615 - val_accuracy: 0.9219 - val_loss: 0.2490 - learning_rate: 0.0010
# Epoch 11/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9340 - loss: 0.2255 - val_accuracy: 0.8906 - val_loss: 0.2569 - learning_rate: 0.0010
# Epoch 12/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9191 - loss: 0.2598 - val_accuracy: 0.8906 - val_loss: 0.2534 - learning_rate: 0.0010
# Epoch 13/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9298 - loss: 0.1861 - val_accuracy: 0.9375 - val_loss: 0.2033 - learning_rate: 2.0000e-04
# Epoch 14/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9649 - loss: 0.1300 - val_accuracy: 0.9375 - val_loss: 0.1836 - learning_rate: 2.0000e-04
# Epoch 15/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9251 - loss: 0.1743 - val_accuracy: 0.9375 - val_loss: 0.1968 - learning_rate: 2.0000e-04
# Epoch 16/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9580 - loss: 0.1550 - val_accuracy: 0.9609 - val_loss: 0.1652 - learning_rate: 2.0000e-04
# Epoch 17/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9680 - loss: 0.1196 - val_accuracy: 0.9375 - val_loss: 0.1799 - learning_rate: 2.0000e-04
# Epoch 18/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9657 - loss: 0.1025 - val_accuracy: 0.9609 - val_loss: 0.1648 - learning_rate: 2.0000e-04
# Epoch 19/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9741 - loss: 0.0823 - val_accuracy: 0.9531 - val_loss: 0.1775 - learning_rate: 2.0000e-04
# Epoch 20/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9710 - loss: 0.0934 - val_accuracy: 0.9297 - val_loss: 0.1847 - learning_rate: 2.0000e-04
# Epoch 21/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9682 - loss: 0.0822 - val_accuracy: 0.9375 - val_loss: 0.1825 - learning_rate: 1.0000e-04
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip_8 (RandomFlip)      │ (8, 64, 64, 3)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_contrast_8               │ (8, 64, 64, 3)         │             0 │
# │ (RandomContrast)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_24 (Conv2D)              │ (8, 64, 64, 64)        │        15,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_24 (MaxPooling2D) │ (8, 16, 16, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_25 (Conv2D)              │ (8, 16, 16, 32)        │        51,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_25 (MaxPooling2D) │ (8, 6, 6, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_26 (Conv2D)              │ (8, 6, 6, 32)          │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_26 (MaxPooling2D) │ (8, 3, 3, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (8, 3, 3, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_8 (Flatten)             │ (8, 288)               │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (8, 64)                │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (8, 64)                │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (8, 3)                 │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 296,843 (1.13 MB)
#  Trainable params: 98,947 (386.51 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 197,896 (773.04 KB)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# before [[4.12388071e-02 2.36568361e-04 9.58524644e-01]
#  [9.99418259e-01 5.80475025e-04 1.29494151e-06]
#  [9.97285962e-01 2.46958365e-03 2.44454044e-04]
#  [1.87117228e-04 8.16520696e-06 9.99804676e-01]
#  [9.99811828e-01 1.86611549e-04 1.58366072e-06]
#  [9.99977708e-01 2.22939070e-05 9.64710187e-11]
#  [9.99971151e-01 2.77375693e-05 1.01465423e-06]
#  [5.15320040e-02 9.47122037e-01 1.34597835e-03]
#  [9.99922633e-01 7.65153018e-05 8.56019085e-07]
#  [9.99957204e-01 3.45896369e-05 8.25986353e-06]
#  [2.05958102e-04 9.70022462e-04 9.98823941e-01]
#  [2.50057387e-03 9.97111917e-01 3.87528475e-04]
#  [6.35034621e-01 3.55181366e-01 9.78402235e-03]
#  [6.33619144e-04 1.71320498e-04 9.99195158e-01]
#  [9.99990463e-01 9.53169274e-06 2.34381653e-10]
#  [2.89908203e-04 9.66858526e-04 9.98743236e-01]
#  [5.89706819e-04 9.95737076e-01 3.67321307e-03]
#  [2.56448930e-05 5.34868923e-05 9.99920845e-01]
#  [4.06987872e-03 9.93744671e-01 2.18548020e-03]
#  [9.42033694e-06 8.29724071e-04 9.99160886e-01]
#  [2.84833878e-01 6.85358286e-01 2.98078358e-02]
#  [1.26050293e-01 1.34323128e-02 8.60517383e-01]
#  [5.90975583e-01 4.08547997e-01 4.76425514e-04]
#  [1.26690438e-05 5.34022183e-06 9.99981999e-01]
#  [8.20325553e-01 9.53882188e-03 1.70135602e-01]
#  [9.25084460e-05 1.22303254e-05 9.99895215e-01]
#  [1.03556173e-04 8.46110634e-05 9.99811828e-01]
#  [5.39207656e-04 6.23886590e-05 9.99398351e-01]
#  [9.98106241e-01 6.30910974e-04 1.26279646e-03]
#  [4.25115606e-04 8.74988735e-04 9.98699903e-01]
#  [1.24180946e-03 2.29553742e-04 9.98528719e-01]
#  [2.07013160e-04 4.19794997e-05 9.99751031e-01]
#  [9.99296427e-01 6.84888219e-04 1.87189016e-05]
#  [9.84241307e-01 1.56425890e-02 1.16197465e-04]
#  [9.99977589e-01 2.11797105e-05 1.17503180e-06]
#  [9.54235077e-01 4.57649827e-02 2.88814278e-10]
#  [9.99983430e-01 1.65701404e-05 2.29192776e-09]
#  [9.83423471e-01 7.36465445e-03 9.21180286e-03]
#  [6.52410788e-03 9.92640913e-01 8.34935636e-04]
#  [7.59118609e-03 9.51206923e-01 4.12019417e-02]
#  [1.71939164e-01 6.74786150e-01 1.53274670e-01]
#  [7.36518632e-05 8.09139019e-05 9.99845386e-01]
#  [9.92085278e-01 7.82158971e-03 9.30881724e-05]
#  [9.63254552e-03 9.88937974e-01 1.42942893e-03]
#  [3.44295637e-03 9.88938093e-01 7.61898747e-03]
#  [9.98883069e-01 1.09097199e-03 2.59902590e-05]
#  [2.14798614e-01 2.61721522e-01 5.23479819e-01]
#  [9.99957442e-01 4.15982504e-05 9.71655368e-07]
#  [1.46282194e-02 4.31209803e-02 9.42250788e-01]
#  [9.99986410e-01 1.33893809e-05 2.61360015e-07]
#  [2.72175274e-03 6.71710353e-04 9.96606588e-01]
#  [2.37423882e-01 7.51858592e-01 1.07175754e-02]
#  [1.93415719e-04 6.75836327e-06 9.99799788e-01]
#  [7.44336903e-01 3.38816866e-02 2.21781462e-01]
#  [9.99997616e-01 2.39808014e-06 9.88045556e-09]
#  [9.16706324e-01 6.12672828e-02 2.20264383e-02]
#  [9.31027710e-01 5.07782623e-02 1.81940328e-02]
#  [4.74968292e-05 4.32461684e-06 9.99948263e-01]
#  [9.98794317e-01 1.17213593e-03 3.35406476e-05]
#  [2.67403096e-01 5.62585890e-03 7.26971149e-01]
#  [3.95067083e-03 9.91507888e-01 4.54145856e-03]
#  [9.98812199e-01 1.16019626e-03 2.76026985e-05]
#  [1.37479336e-04 1.13811449e-03 9.98724401e-01]
#  [7.22817004e-01 2.65525550e-01 1.16574671e-02]
#  [2.62556132e-05 9.42274928e-05 9.99879479e-01]
#  [7.28355546e-04 6.13213706e-05 9.99210238e-01]
#  [9.19621289e-02 8.93713176e-01 1.43246595e-02]
#  [1.94802955e-02 7.27333128e-03 9.73246396e-01]
#  [4.90797171e-03 8.44212413e-01 1.50879577e-01]
#  [9.98850584e-01 1.08629791e-03 6.31638832e-05]
#  [2.36728556e-05 1.63538178e-04 9.99812782e-01]
#  [9.99952316e-01 4.28788117e-05 4.73208047e-06]
#  [9.99977827e-01 2.21441405e-05 2.10639883e-09]
#  [9.99977350e-01 2.27037290e-05 1.76145587e-09]
#  [8.54692161e-01 1.33570999e-01 1.17367785e-02]
#  [2.03844300e-03 9.91992831e-01 5.96865127e-03]
#  [9.98540998e-01 1.45839085e-03 5.46284980e-07]
#  [1.51068627e-04 6.65085332e-04 9.99183834e-01]
#  [8.82947716e-05 3.02688604e-05 9.99881387e-01]
#  [9.99839425e-01 1.22401980e-04 3.81539649e-05]
#  [9.99930382e-01 6.95648050e-05 2.75724350e-08]
#  [1.10175515e-05 8.41286746e-05 9.99904871e-01]
#  [1.74651708e-04 9.49635506e-01 5.01899086e-02]
#  [9.99972820e-01 2.54758324e-05 1.70691112e-06]
#  [1.63920427e-04 2.72010397e-02 9.72634971e-01]
#  [9.93271649e-01 6.68855291e-03 3.97620424e-05]
#  [9.99929428e-01 6.58604986e-05 4.70352370e-06]
#  [3.90047615e-04 9.95315671e-01 4.29424737e-03]
#  [9.99997497e-01 2.45107935e-06 1.80337045e-09]
#  [3.71529604e-04 6.58041390e-05 9.99562681e-01]
#  [3.25661898e-01 5.66208875e-03 6.68676078e-01]
#  [1.17181037e-02 1.69368694e-03 9.86588180e-01]
#  [9.97951686e-01 2.01802677e-03 3.03192846e-05]
#  [5.22151822e-05 1.38431296e-05 9.99933958e-01]
#  [3.10244989e-02 9.65817392e-01 3.15813534e-03]
#  [9.99855042e-01 1.44959384e-04 4.75506834e-09]
#  [3.87556195e-01 6.24125730e-03 6.06202543e-01]
#  [9.09841910e-05 8.41285218e-04 9.99067724e-01]
#  [9.90923145e-04 9.98529434e-01 4.79633338e-04]
#  [9.71290410e-01 2.84155235e-02 2.94100289e-04]
#  [3.98212159e-03 9.87949491e-01 8.06843117e-03]
#  [1.24335711e-04 3.21944717e-05 9.99843478e-01]
#  [2.73803272e-03 9.96538401e-01 7.23524194e-04]
#  [4.13571578e-03 7.22212135e-05 9.95792150e-01]
#  [6.01499269e-05 9.90400895e-06 9.99929905e-01]
#  [9.99988437e-01 1.15877674e-05 5.35408995e-10]
#  [5.33656180e-02 7.67207891e-02 8.69913697e-01]
#  [9.99999881e-01 1.37102361e-07 8.86651219e-15]
#  [9.99960065e-01 3.99589953e-05 9.87079307e-10]
#  [9.96460974e-01 3.30231804e-03 2.36738342e-04]
#  [9.20851671e-05 9.99788582e-01 1.19400596e-04]
#  [6.58547133e-03 9.91804838e-01 1.60970748e-03]
#  [5.57928979e-01 3.94988269e-01 4.70827036e-02]
#  [7.47610784e-07 2.57046594e-07 9.99999046e-01]
#  [3.12720123e-03 9.96313155e-01 5.59701584e-04]
#  [2.81416550e-02 3.91833335e-01 5.80025077e-01]
#  [3.56566488e-05 4.95776158e-06 9.99959350e-01]
#  [9.99797523e-01 2.02514493e-04 1.55157629e-08]
#  [9.71529603e-01 1.51742797e-03 2.69530006e-02]
#  [1.80664589e-03 3.79240373e-03 9.94400918e-01]
#  [4.03568288e-03 9.90165055e-01 5.79924276e-03]
#  [2.62318790e-05 7.34231784e-04 9.99239564e-01]
#  [5.81266358e-04 9.92549896e-01 6.86882762e-03]
#  [4.41829953e-03 1.13667839e-03 9.94445145e-01]
#  [9.99749839e-01 2.49895355e-04 2.54790194e-07]
#  [8.58837593e-05 1.62561256e-02 9.83658016e-01]
#  [6.04649961e-01 2.38087121e-02 3.71541291e-01]
#  [1.43435400e-05 2.05769466e-04 9.99779999e-01]]
# probabilities [2 0 0 2 0 0 0 1 0 0 2 1 0 2 0 2 1 2 1 2 1 2 0 2 0 2 2 2 0 2 2 2 0 0 0 0 0
#  0 1 1 1 2 0 1 1 0 2 0 2 0 2 1 2 0 0 0 0 2 0 2 1 0 2 0 2 2 1 2 1 0 2 0 0 0
#  0 1 0 2 2 0 0 2 1 0 2 0 0 1 0 2 2 2 0 2 1 0 2 2 1 0 1 2 1 2 2 0 2 0 0 0 1
#  1 0 2 1 2 2 0 0 2 1 2 1 2 0 2 0 2]

# %% [markdown]
# 4. swish
# training time 14.6s

# %%
# variables for hyperparameters
batch_size = 8
epochs = 50
num_classes = len(label_names)
activation = 'relu'
activation_conv = 'swish'  # LeakyReLU 
layer_count = 2
num_neurons = 64

# define model structure
# with keras, we can use a model's add() function to add layers to the network one by one
model = Sequential()

# data augmentation (this can also be done beforehand - but don't augment the test dataset!)
model.add(RandomFlip('horizontal'))
model.add(RandomContrast(0.1))
#model.add(RandomBrightness(0.1))
#model.add(RandomRotation(0.2))

# first, we add some convolution layers followed by max pooling
model.add(Conv2D(64, kernel_size=(9, 9), activation=activation_conv, input_shape=(SIZE[0], SIZE[1], COLOR_CHANNELS), padding='same'))
model.add(MaxPooling2D(pool_size=(4, 4), padding='same'))

model.add(Conv2D(32, (5, 5), activation=activation_conv, padding='same'))
model.add(MaxPooling2D(pool_size=(3, 3), padding='same'))

model.add(Conv2D(32, (3, 3), activation=activation_conv, padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))

# dropout layers can drop part of the data during each epoch - this prevents overfitting
model.add(Dropout(0.2))

# after the convolution layers, we have to flatten the data so it can be fed into fully connected layers
model.add(Flatten())

# add some fully connected layers ("Dense")
for i in range(layer_count - 1):
    model.add(Dense(num_neurons, activation=activation))

model.add(Dense(num_neurons, activation=activation))

# for classification, the last layer has to use the softmax activation function, which gives us probabilities for each category
model.add(Dense(num_classes, activation='softmax'))

# specify loss function, optimizer and evaluation metrics
# for classification, categorial crossentropy is used as a loss function
# use the adam optimizer unless you have a good reason not to
model.compile(loss=categorical_crossentropy, optimizer="adam", metrics=['accuracy'])

# define callback functions that react to the model's behavior during training
# in this example, we reduce the learning rate once we get stuck and early stopping
# to cancel the training if there are no improvements for a certain amount of epochs
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.0001)
stop_early = EarlyStopping(monitor='val_loss', patience=3)

history = model.fit(
    X_train,
    train_label,
    batch_size=batch_size,
    epochs=epochs,
    verbose=1,
    validation_data=(X_test, test_label),
    callbacks=[reduce_lr, stop_early]
)

model.summary()

loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

fig = plt.figure(figsize=(15, 7))
ax = plt.gca()

ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy (Line), Loss (Dashes)')

ax.axhline(1, color='gray')

plt.plot(accuracy, color='blue')
plt.plot(val_accuracy, color='orange')
plt.plot(loss, '--', color='blue', alpha=0.5)
plt.plot(val_loss, '--', color='orange', alpha=0.5)

model.save('gesture_recognition_4.keras')

# let the model make predictions for our training data
y_predictions = model.predict(X_test)

# we get a 2D numpy array with probabilities for each category
print('before', y_predictions)

# to build a confusion matrix, we have to convert it to classifications
# this can be done by using the argmax() function to set the probability to 1 and the rest to 0
y_predictions = np.argmax(y_predictions, axis=1)

print('probabilities', y_predictions)

# create and plot confusion matrix
conf_matrix = confusion_matrix(y_test, y_predictions)

fig = plt.figure(figsize=(10, 10))

ConfusionMatrixDisplay(conf_matrix, display_labels=label_names).plot(ax=plt.gca())

plt.xticks(rotation=90, ha='center')
pass
# Out:
# Epoch 1/50
# C:\pythonstuff\assignment-5-cnn-johnnyklein\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.3937 - loss: 1.0722 - val_accuracy: 0.4688 - val_loss: 1.0050 - learning_rate: 0.0010
# Epoch 2/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5043 - loss: 0.9718 - val_accuracy: 0.5000 - val_loss: 1.0467 - learning_rate: 0.0010
# Epoch 3/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6784 - loss: 0.7802 - val_accuracy: 0.7109 - val_loss: 0.6885 - learning_rate: 0.0010
# Epoch 4/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7291 - loss: 0.6342 - val_accuracy: 0.8438 - val_loss: 0.3838 - learning_rate: 0.0010
# Epoch 5/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8666 - loss: 0.3764 - val_accuracy: 0.9141 - val_loss: 0.2536 - learning_rate: 0.0010
# Epoch 6/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9277 - loss: 0.1931 - val_accuracy: 0.9062 - val_loss: 0.2565 - learning_rate: 0.0010
# Epoch 7/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8961 - loss: 0.2515 - val_accuracy: 0.9531 - val_loss: 0.1997 - learning_rate: 0.0010
# Epoch 8/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9522 - loss: 0.1357 - val_accuracy: 0.9141 - val_loss: 0.3225 - learning_rate: 0.0010
# Epoch 9/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9315 - loss: 0.1896 - val_accuracy: 0.9453 - val_loss: 0.1977 - learning_rate: 0.0010
# Epoch 10/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9506 - loss: 0.1569 - val_accuracy: 0.9297 - val_loss: 0.1934 - learning_rate: 0.0010
# Epoch 11/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9707 - loss: 0.0837 - val_accuracy: 0.9297 - val_loss: 0.2655 - learning_rate: 0.0010
# Epoch 12/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9734 - loss: 0.1008 - val_accuracy: 0.8906 - val_loss: 0.4397 - learning_rate: 0.0010
# Epoch 13/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9862 - loss: 0.0477 - val_accuracy: 0.9375 - val_loss: 0.2411 - learning_rate: 2.0000e-04
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip_9 (RandomFlip)      │ (8, 64, 64, 3)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_contrast_9               │ (8, 64, 64, 3)         │             0 │
# │ (RandomContrast)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_27 (Conv2D)              │ (8, 64, 64, 64)        │        15,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_27 (MaxPooling2D) │ (8, 16, 16, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_28 (Conv2D)              │ (8, 16, 16, 32)        │        51,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_28 (MaxPooling2D) │ (8, 6, 6, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_29 (Conv2D)              │ (8, 6, 6, 32)          │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_29 (MaxPooling2D) │ (8, 3, 3, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (8, 3, 3, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_9 (Flatten)             │ (8, 288)               │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_27 (Dense)                │ (8, 64)                │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (8, 64)                │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (8, 3)                 │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 296,843 (1.13 MB)
#  Trainable params: 98,947 (386.51 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 197,896 (773.04 KB)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# before [[1.10870635e-03 1.52582470e-05 9.98876035e-01]
#  [9.99880672e-01 1.15942938e-04 3.31372848e-06]
#  [9.99756753e-01 1.26401341e-04 1.16777766e-04]
#  [3.68122492e-05 6.03802903e-07 9.99962568e-01]
#  [9.99954343e-01 3.26949230e-05 1.30467060e-05]
#  [9.99994278e-01 5.72389126e-06 3.41198469e-09]
#  [9.99992967e-01 2.88673436e-06 4.16309786e-06]
#  [2.94199353e-03 9.97048676e-01 9.29905946e-06]
#  [9.99954224e-01 3.07332521e-05 1.50610695e-05]
#  [9.99543309e-01 3.74628784e-04 8.20884816e-05]
#  [1.95842760e-04 2.24962569e-05 9.99781668e-01]
#  [4.10169423e-06 9.99995708e-01 1.64252981e-07]
#  [5.48819959e-01 4.47580278e-01 3.59969493e-03]
#  [1.75764004e-03 3.15640209e-05 9.98210788e-01]
#  [9.99999762e-01 2.09004270e-07 2.53910049e-08]
#  [2.94642989e-04 1.30526569e-05 9.99692321e-01]
#  [8.14256566e-07 9.99999166e-01 4.59151606e-09]
#  [6.16725129e-06 3.81834226e-08 9.99993801e-01]
#  [1.46546925e-04 9.99849558e-01 3.89913976e-06]
#  [1.00701482e-06 6.01670980e-09 9.99999046e-01]
#  [3.83473068e-01 5.85321367e-01 3.12055647e-02]
#  [2.35626776e-05 2.12698737e-07 9.99976158e-01]
#  [5.24728060e-01 4.42644507e-01 3.26275118e-02]
#  [6.22595849e-07 1.23698829e-09 9.99999404e-01]
#  [9.92673457e-01 1.05814647e-03 6.26832386e-03]
#  [8.53539768e-06 4.48527615e-08 9.99991417e-01]
#  [2.27512137e-05 1.06359107e-06 9.99976158e-01]
#  [1.14095013e-03 9.15957662e-06 9.98849869e-01]
#  [9.75952327e-01 1.14896566e-05 2.40361113e-02]
#  [6.19662605e-05 4.84944337e-07 9.99937534e-01]
#  [1.69114769e-03 5.70663287e-05 9.98251736e-01]
#  [1.13737015e-05 1.80085038e-07 9.99988437e-01]
#  [9.99941111e-01 2.56816111e-05 3.33158714e-05]
#  [9.98891175e-01 7.97779576e-05 1.02910784e-03]
#  [9.99999046e-01 6.38572089e-07 3.46867893e-07]
#  [9.99919653e-01 8.03280273e-05 2.53860168e-08]
#  [9.99922514e-01 7.72606509e-05 1.95021229e-07]
#  [9.99961138e-01 2.08442566e-06 3.67932444e-05]
#  [1.31008518e-03 9.98661160e-01 2.87449566e-05]
#  [4.25707462e-04 9.99557793e-01 1.64921585e-05]
#  [2.84483912e-03 9.97103631e-01 5.14963249e-05]
#  [2.18125060e-04 3.82639428e-07 9.99781549e-01]
#  [9.89175260e-01 3.46520421e-04 1.04781771e-02]
#  [1.70938481e-04 9.99828219e-01 7.72746432e-07]
#  [2.86587339e-04 9.99694586e-01 1.88796403e-05]
#  [9.99346316e-01 4.88501682e-04 1.65081437e-04]
#  [3.20569053e-03 1.19936978e-03 9.95594919e-01]
#  [9.99933720e-01 2.35546922e-05 4.26501210e-05]
#  [2.88775116e-01 1.22462036e-02 6.98978603e-01]
#  [9.99992132e-01 7.90939248e-06 2.55156269e-08]
#  [3.67353787e-04 1.47727369e-05 9.99617815e-01]
#  [3.66952240e-01 6.12985373e-01 2.00623274e-02]
#  [6.97898122e-06 5.71455061e-08 9.99992967e-01]
#  [6.43552542e-01 1.37494341e-03 3.55072558e-01]
#  [9.99997497e-01 2.37993072e-06 6.09402875e-08]
#  [9.98902798e-01 4.22772660e-04 6.74482842e-04]
#  [8.76004457e-01 1.14769337e-03 1.22847900e-01]
#  [4.14677395e-08 1.61205171e-09 1.00000000e+00]
#  [9.99948144e-01 4.85302480e-05 3.28684268e-06]
#  [2.08422616e-02 1.61829030e-05 9.79141533e-01]
#  [4.67088219e-04 9.99530554e-01 2.42455326e-06]
#  [9.92361784e-01 7.48394150e-03 1.54237117e-04]
#  [4.13371570e-04 1.21921895e-03 9.98367488e-01]
#  [1.31112427e-01 8.68741035e-01 1.46463877e-04]
#  [2.65360654e-06 7.67235306e-08 9.99997258e-01]
#  [4.29618929e-04 9.72458565e-06 9.99560654e-01]
#  [3.14325024e-03 9.96829808e-01 2.69813845e-05]
#  [1.85707547e-02 1.36311643e-03 9.80066180e-01]
#  [4.06093430e-04 9.99582231e-01 1.16586198e-05]
#  [9.97437954e-01 8.69733514e-04 1.69220171e-03]
#  [1.31533598e-05 1.12763530e-06 9.99985814e-01]
#  [9.99927640e-01 4.83992371e-05 2.39344918e-05]
#  [9.99975920e-01 2.27099772e-05 1.32657692e-06]
#  [9.99904990e-01 9.14756238e-05 3.58962166e-06]
#  [9.85289395e-01 1.02291526e-02 4.48148651e-03]
#  [1.34740512e-05 9.99986410e-01 6.99582685e-08]
#  [9.99745071e-01 3.16407641e-05 2.23361596e-04]
#  [1.74189699e-05 3.73082776e-06 9.99978900e-01]
#  [1.77357706e-05 3.89561637e-06 9.99978304e-01]
#  [9.99999642e-01 2.93450825e-07 6.46644267e-08]
#  [9.99815285e-01 1.82887132e-04 1.87964270e-06]
#  [1.96228166e-06 3.43423181e-07 9.99997735e-01]
#  [2.61409991e-06 9.99987245e-01 1.01080786e-05]
#  [9.99967098e-01 6.24482436e-06 2.67605137e-05]
#  [4.75975048e-06 4.91439948e-07 9.99994755e-01]
#  [9.99688745e-01 3.02822998e-04 8.51791174e-06]
#  [9.99811709e-01 1.72759101e-05 1.70990927e-04]
#  [2.49393663e-04 9.99471128e-01 2.79513857e-04]
#  [9.99996305e-01 3.72749241e-06 5.84353765e-09]
#  [4.27477108e-03 6.56085831e-06 9.95718658e-01]
#  [8.26819181e-01 6.66888838e-04 1.72513932e-01]
#  [5.72566059e-04 5.02764196e-05 9.99377191e-01]
#  [9.98037398e-01 1.86833763e-03 9.42652769e-05]
#  [9.56903241e-05 3.63063435e-07 9.99903917e-01]
#  [8.19131732e-04 9.99175847e-01 5.04146738e-06]
#  [9.99265969e-01 7.33813620e-04 1.94075596e-07]
#  [9.39306676e-01 1.02802645e-03 5.96652627e-02]
#  [2.19931953e-05 1.20005222e-06 9.99976873e-01]
#  [3.82565413e-05 9.99961734e-01 4.22432045e-08]
#  [9.89964068e-01 4.74796956e-03 5.28794387e-03]
#  [1.39893993e-04 9.99853730e-01 6.37451285e-06]
#  [1.20331693e-04 2.14666875e-06 9.99877453e-01]
#  [3.92147776e-05 9.99960661e-01 1.30709608e-07]
#  [2.85075861e-03 9.82292022e-06 9.97139335e-01]
#  [1.89849322e-06 7.42217665e-08 9.99997973e-01]
#  [9.99999523e-01 4.55067578e-07 7.91808286e-10]
#  [2.35595414e-03 1.11517140e-04 9.97532487e-01]
#  [9.99999285e-01 7.14959640e-07 1.72081238e-11]
#  [9.99906540e-01 9.33341507e-05 8.65315926e-08]
#  [9.98736203e-01 1.02752540e-03 2.36294320e-04]
#  [2.12248528e-06 9.99997735e-01 1.37316661e-07]
#  [2.08171201e-03 9.97717261e-01 2.01066170e-04]
#  [7.93270767e-01 2.02938855e-01 3.79043538e-03]
#  [2.51613926e-07 9.70688308e-10 9.99999762e-01]
#  [1.20246201e-04 9.99879122e-01 6.21468075e-07]
#  [9.17724371e-02 1.28970265e-01 7.79257298e-01]
#  [5.94039102e-06 1.75453934e-07 9.99993920e-01]
#  [9.99975920e-01 2.28404278e-05 1.19272261e-06]
#  [8.88841033e-01 1.64101133e-04 1.10994853e-01]
#  [6.23094384e-05 3.90920395e-05 9.99898553e-01]
#  [2.44529359e-03 9.97330189e-01 2.24548043e-04]
#  [4.41352995e-06 1.62522394e-06 9.99993920e-01]
#  [4.92338091e-04 9.99495149e-01 1.25309352e-05]
#  [3.12817446e-03 2.18908917e-05 9.96849954e-01]
#  [9.99993324e-01 6.27757299e-06 3.87140659e-07]
#  [1.25765864e-05 4.56849870e-04 9.99530554e-01]
#  [7.38827363e-02 2.40351292e-05 9.26093221e-01]
#  [7.41641770e-08 1.00043596e-09 9.99999881e-01]]
# probabilities [2 0 0 2 0 0 0 1 0 0 2 1 0 2 0 2 1 2 1 2 1 2 0 2 0 2 2 2 0 2 2 2 0 0 0 0 0
#  0 1 1 1 2 0 1 1 0 2 0 2 0 2 1 2 0 0 0 0 2 0 2 1 0 2 1 2 2 1 2 1 0 2 0 0 0
#  0 1 0 2 2 0 0 2 1 0 2 0 0 1 0 2 0 2 0 2 1 0 0 2 1 0 1 2 1 2 2 0 2 0 0 0 1
#  1 0 2 1 2 2 0 0 2 1 2 1 2 0 2 2 2]

# %% [markdown]
# 5.linear

# %%
# variables for hyperparameters
batch_size = 8
epochs = 50
num_classes = len(label_names)
activation = 'relu'
activation_conv = 'linear'  # LeakyReLU 
layer_count = 2
num_neurons = 64

# define model structure
# with keras, we can use a model's add() function to add layers to the network one by one
model = Sequential()

# data augmentation (this can also be done beforehand - but don't augment the test dataset!)
model.add(RandomFlip('horizontal'))
model.add(RandomContrast(0.1))
#model.add(RandomBrightness(0.1))
#model.add(RandomRotation(0.2))

# first, we add some convolution layers followed by max pooling
model.add(Conv2D(64, kernel_size=(9, 9), activation=activation_conv, input_shape=(SIZE[0], SIZE[1], COLOR_CHANNELS), padding='same'))
model.add(MaxPooling2D(pool_size=(4, 4), padding='same'))

model.add(Conv2D(32, (5, 5), activation=activation_conv, padding='same'))
model.add(MaxPooling2D(pool_size=(3, 3), padding='same'))

model.add(Conv2D(32, (3, 3), activation=activation_conv, padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))

# dropout layers can drop part of the data during each epoch - this prevents overfitting
model.add(Dropout(0.2))

# after the convolution layers, we have to flatten the data so it can be fed into fully connected layers
model.add(Flatten())

# add some fully connected layers ("Dense")
for i in range(layer_count - 1):
    model.add(Dense(num_neurons, activation=activation))

model.add(Dense(num_neurons, activation=activation))

# for classification, the last layer has to use the softmax activation function, which gives us probabilities for each category
model.add(Dense(num_classes, activation='softmax'))

# specify loss function, optimizer and evaluation metrics
# for classification, categorial crossentropy is used as a loss function
# use the adam optimizer unless you have a good reason not to
model.compile(loss=categorical_crossentropy, optimizer="adam", metrics=['accuracy'])

# define callback functions that react to the model's behavior during training
# in this example, we reduce the learning rate once we get stuck and early stopping
# to cancel the training if there are no improvements for a certain amount of epochs
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.0001)
stop_early = EarlyStopping(monitor='val_loss', patience=3)

history = model.fit(
    X_train,
    train_label,
    batch_size=batch_size,
    epochs=epochs,
    verbose=1,
    validation_data=(X_test, test_label),
    callbacks=[reduce_lr, stop_early]
)

model.summary()

loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

fig = plt.figure(figsize=(15, 7))
ax = plt.gca()

ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy (Line), Loss (Dashes)')

ax.axhline(1, color='gray')

plt.plot(accuracy, color='blue')
plt.plot(val_accuracy, color='orange')
plt.plot(loss, '--', color='blue', alpha=0.5)
plt.plot(val_loss, '--', color='orange', alpha=0.5)

model.save('gesture_recognition_5.keras')

# let the model make predictions for our training data
y_predictions = model.predict(X_test)

# we get a 2D numpy array with probabilities for each category
print('before', y_predictions)

# to build a confusion matrix, we have to convert it to classifications
# this can be done by using the argmax() function to set the probability to 1 and the rest to 0
y_predictions = np.argmax(y_predictions, axis=1)

print('probabilities', y_predictions)

# create and plot confusion matrix
conf_matrix = confusion_matrix(y_test, y_predictions)

fig = plt.figure(figsize=(10, 10))

ConfusionMatrixDisplay(conf_matrix, display_labels=label_names).plot(ax=plt.gca())

plt.xticks(rotation=90, ha='center')
pass
# Out:
# Epoch 1/50
# C:\pythonstuff\assignment-5-cnn-johnnyklein\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.3686 - loss: 1.1413 - val_accuracy: 0.3594 - val_loss: 1.0638 - learning_rate: 0.0010
# Epoch 2/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4290 - loss: 1.0669 - val_accuracy: 0.5469 - val_loss: 0.9566 - learning_rate: 0.0010
# Epoch 3/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4872 - loss: 0.9948 - val_accuracy: 0.6797 - val_loss: 0.8025 - learning_rate: 0.0010
# Epoch 4/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6208 - loss: 0.8472 - val_accuracy: 0.7188 - val_loss: 0.6355 - learning_rate: 0.0010
# Epoch 5/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8057 - loss: 0.5074 - val_accuracy: 0.8516 - val_loss: 0.4194 - learning_rate: 0.0010
# Epoch 6/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8835 - loss: 0.3024 - val_accuracy: 0.9141 - val_loss: 0.3413 - learning_rate: 0.0010
# Epoch 7/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9288 - loss: 0.2239 - val_accuracy: 0.9062 - val_loss: 0.3175 - learning_rate: 0.0010
# Epoch 8/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9204 - loss: 0.2349 - val_accuracy: 0.8828 - val_loss: 0.3261 - learning_rate: 0.0010
# Epoch 9/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9255 - loss: 0.2221 - val_accuracy: 0.9141 - val_loss: 0.2206 - learning_rate: 0.0010
# Epoch 10/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9382 - loss: 0.1451 - val_accuracy: 0.9609 - val_loss: 0.1413 - learning_rate: 0.0010
# Epoch 11/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9726 - loss: 0.0955 - val_accuracy: 0.9297 - val_loss: 0.1956 - learning_rate: 0.0010
# Epoch 12/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9768 - loss: 0.0695 - val_accuracy: 0.9219 - val_loss: 0.1994 - learning_rate: 0.0010
# Epoch 13/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9848 - loss: 0.0305 - val_accuracy: 0.9453 - val_loss: 0.1731 - learning_rate: 2.0000e-04
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip_10 (RandomFlip)     │ (8, 64, 64, 3)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_contrast_10              │ (8, 64, 64, 3)         │             0 │
# │ (RandomContrast)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_30 (Conv2D)              │ (8, 64, 64, 64)        │        15,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_30 (MaxPooling2D) │ (8, 16, 16, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_31 (Conv2D)              │ (8, 16, 16, 32)        │        51,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_31 (MaxPooling2D) │ (8, 6, 6, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_32 (Conv2D)              │ (8, 6, 6, 32)          │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_32 (MaxPooling2D) │ (8, 3, 3, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (8, 3, 3, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_10 (Flatten)            │ (8, 288)               │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_30 (Dense)                │ (8, 64)                │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_31 (Dense)                │ (8, 64)                │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_32 (Dense)                │ (8, 3)                 │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 296,843 (1.13 MB)
#  Trainable params: 98,947 (386.51 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 197,896 (773.04 KB)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# before [[1.53877493e-02 3.96278629e-04 9.84215915e-01]
#  [9.99983311e-01 1.50027454e-05 1.70344094e-06]
#  [9.98618841e-01 1.78879083e-04 1.20225223e-03]
#  [1.04813807e-05 3.99635292e-06 9.99985456e-01]
#  [9.99962926e-01 2.21083610e-05 1.50551832e-05]
#  [9.99999762e-01 2.27092372e-07 6.70351663e-10]
#  [9.99999523e-01 8.08429519e-08 3.85445503e-07]
#  [4.85210419e-01 5.14008164e-01 7.81473413e-04]
#  [9.99973059e-01 2.55983632e-05 1.26395651e-06]
#  [9.99939203e-01 4.37091112e-05 1.70283220e-05]
#  [1.91549514e-03 2.52344203e-03 9.95561004e-01]
#  [1.74128218e-05 9.99981642e-01 9.98669179e-07]
#  [8.44747961e-01 1.40517578e-01 1.47344628e-02]
#  [8.01606438e-05 1.42366931e-04 9.99777377e-01]
#  [9.99999523e-01 4.75547864e-07 5.34138458e-08]
#  [1.97513669e-04 2.51265359e-03 9.97289896e-01]
#  [5.26707851e-08 1.00000000e+00 2.14511719e-09]
#  [5.05202297e-05 1.86641646e-05 9.99930739e-01]
#  [6.43400149e-03 9.89851117e-01 3.71490559e-03]
#  [2.85692404e-05 1.27758778e-06 9.99970078e-01]
#  [5.87262332e-01 2.28123754e-01 1.84613898e-01]
#  [4.11163666e-04 1.13593836e-04 9.99475300e-01]
#  [7.87376702e-01 2.06019714e-01 6.60358788e-03]
#  [5.94114454e-06 9.68296445e-06 9.99984384e-01]
#  [9.93189991e-01 7.17179151e-04 6.09281054e-03]
#  [6.84950501e-05 1.36025174e-05 9.99917865e-01]
#  [5.99304694e-05 5.10457448e-06 9.99934912e-01]
#  [1.21085133e-04 6.91024543e-05 9.99809802e-01]
#  [9.99274075e-01 4.20088145e-06 7.21781340e-04]
#  [5.36716497e-03 4.28395579e-04 9.94204342e-01]
#  [8.95056437e-05 3.33888514e-04 9.99576628e-01]
#  [1.37860798e-05 1.52059920e-05 9.99970913e-01]
#  [9.99811113e-01 5.21688999e-05 1.36721050e-04]
#  [9.99897838e-01 3.68347974e-05 6.52643212e-05]
#  [9.99999762e-01 6.19211065e-08 8.87578082e-08]
#  [9.99737680e-01 2.62193789e-04 7.47355173e-08]
#  [9.99962449e-01 1.75427140e-05 2.00075665e-05]
#  [9.99968886e-01 2.14811753e-05 9.60186571e-06]
#  [6.24959241e-04 9.99250352e-01 1.24649960e-04]
#  [8.47800169e-03 9.80740488e-01 1.07815256e-02]
#  [6.43985253e-03 9.83226836e-01 1.03332922e-02]
#  [6.16794778e-03 3.53942887e-04 9.93478060e-01]
#  [9.99055326e-01 7.61082338e-04 1.83601471e-04]
#  [8.28208140e-05 9.99883771e-01 3.33526805e-05]
#  [1.61929894e-03 9.97892439e-01 4.88280901e-04]
#  [9.99770224e-01 1.93773158e-04 3.59818368e-05]
#  [4.70399745e-02 1.10428771e-02 9.41917062e-01]
#  [9.99991894e-01 5.48290336e-06 2.67239056e-06]
#  [2.62321055e-01 2.26154365e-02 7.15063512e-01]
#  [9.99999046e-01 7.98509632e-07 1.14050266e-07]
#  [8.91690957e-04 2.27913624e-04 9.98880446e-01]
#  [7.81367898e-01 2.07326919e-01 1.13051590e-02]
#  [3.13713863e-05 9.40797872e-06 9.99959230e-01]
#  [7.35951126e-01 8.61068722e-03 2.55438209e-01]
#  [9.99977469e-01 7.54813482e-06 1.50692358e-05]
#  [9.97769833e-01 1.49131962e-03 7.38901261e-04]
#  [9.05562162e-01 1.06335497e-02 8.38043094e-02]
#  [4.85976059e-09 5.58725910e-09 1.00000000e+00]
#  [9.99924541e-01 5.64271832e-05 1.90447481e-05]
#  [8.20396960e-01 2.84298393e-03 1.76760048e-01]
#  [1.42488081e-03 9.98296678e-01 2.78501451e-04]
#  [9.90456998e-01 9.45731718e-03 8.57487830e-05]
#  [5.27946604e-03 1.59905083e-03 9.93121445e-01]
#  [9.60716903e-01 3.92108187e-02 7.22458353e-05]
#  [1.66612917e-05 7.27094630e-06 9.99976039e-01]
#  [2.91845827e-05 6.54408213e-05 9.99905348e-01]
#  [1.73373390e-02 9.81201112e-01 1.46154000e-03]
#  [1.11745298e-01 6.84781186e-03 8.81406844e-01]
#  [3.09308944e-03 9.95535493e-01 1.37147261e-03]
#  [9.99800265e-01 1.56522554e-04 4.32464258e-05]
#  [3.89341694e-05 4.39813812e-06 9.99956608e-01]
#  [9.99981761e-01 3.81054451e-06 1.44007990e-05]
#  [9.99992371e-01 7.38820245e-06 2.87536949e-07]
#  [9.99992609e-01 5.23529070e-06 2.17262277e-06]
#  [9.82679248e-01 1.67671051e-02 5.53671853e-04]
#  [1.11872410e-04 9.99521017e-01 3.67173227e-04]
#  [9.99989271e-01 5.59787486e-06 5.13190435e-06]
#  [3.56527323e-08 1.16330796e-06 9.99998808e-01]
#  [1.45545982e-05 3.42422754e-06 9.99981999e-01]
#  [9.99999642e-01 2.55011884e-07 9.34673139e-08]
#  [9.99535799e-01 4.63491771e-04 6.69258611e-07]
#  [4.02809928e-05 1.74000672e-06 9.99957919e-01]
#  [2.16472617e-05 9.99621034e-01 3.57283803e-04]
#  [9.99974847e-01 1.11412226e-06 2.41050002e-05]
#  [6.50259899e-05 9.49527202e-06 9.99925375e-01]
#  [9.99685645e-01 3.02254542e-04 1.21074072e-05]
#  [9.99764144e-01 8.56717234e-05 1.50149936e-04]
#  [1.40055417e-04 9.99784410e-01 7.55678557e-05]
#  [9.99999642e-01 3.49487976e-07 4.72303219e-09]
#  [1.20290490e-04 5.20219583e-05 9.99827743e-01]
#  [9.75001097e-01 2.08417978e-03 2.29147244e-02]
#  [1.25359872e-03 3.59696802e-04 9.98386741e-01]
#  [9.97795582e-01 2.02125963e-03 1.83210374e-04]
#  [4.04462044e-04 1.30895380e-04 9.99464571e-01]
#  [1.17173158e-02 9.87027228e-01 1.25546334e-03]
#  [9.99968290e-01 2.93200810e-05 2.33704213e-06]
#  [9.56158161e-01 3.46815400e-03 4.03736942e-02]
#  [3.72826507e-05 3.61086786e-05 9.99926567e-01]
#  [3.67140757e-07 9.99999523e-01 9.31670456e-08]
#  [9.96626854e-01 2.70618289e-03 6.67041575e-04]
#  [2.32874518e-04 9.99653339e-01 1.13843686e-04]
#  [1.01349207e-04 6.92164613e-05 9.99829412e-01]
#  [4.13074536e-04 9.99521494e-01 6.54296673e-05]
#  [1.84754992e-03 5.95780439e-04 9.97556686e-01]
#  [2.40701951e-07 9.84708493e-08 9.99999642e-01]
#  [9.99999881e-01 1.45385016e-07 6.28470298e-09]
#  [1.54772293e-04 1.99871167e-04 9.99645352e-01]
#  [9.99999523e-01 4.30515797e-07 2.85896622e-08]
#  [9.99840021e-01 1.44455291e-04 1.54566751e-05]
#  [9.99190867e-01 7.40817515e-04 6.83519684e-05]
#  [1.29879409e-04 9.99832988e-01 3.70806374e-05]
#  [4.16766743e-05 9.99918342e-01 3.99706296e-05]
#  [6.38697803e-01 2.62706667e-01 9.85955596e-02]
#  [1.11515305e-07 1.77001127e-07 9.99999762e-01]
#  [5.04999771e-05 9.99936938e-01 1.26011410e-05]
#  [1.51282579e-01 6.77750111e-01 1.70967281e-01]
#  [2.17666042e-07 1.20168727e-06 9.99998569e-01]
#  [9.99986529e-01 1.23693217e-05 1.06462301e-06]
#  [9.58717883e-01 1.44553342e-04 4.11374979e-02]
#  [1.25418019e-05 7.66207886e-05 9.99910831e-01]
#  [6.60050567e-03 9.89277005e-01 4.12247283e-03]
#  [3.16573132e-05 5.46600086e-06 9.99962807e-01]
#  [3.34563218e-02 9.64390635e-01 2.15309206e-03]
#  [4.86497302e-03 3.52749543e-04 9.94782269e-01]
#  [9.99995828e-01 2.98603072e-06 1.18557216e-06]
#  [4.02412727e-04 1.09863076e-02 9.88611281e-01]
#  [1.51227832e-01 3.60038877e-03 8.45171809e-01]
#  [1.13322176e-05 7.61800379e-07 9.99987960e-01]]
# probabilities [2 0 0 2 0 0 0 1 0 0 2 1 0 2 0 2 1 2 1 2 0 2 0 2 0 2 2 2 0 2 2 2 0 0 0 0 0
#  0 1 1 1 2 0 1 1 0 2 0 2 0 2 0 2 0 0 0 0 2 0 0 1 0 2 0 2 2 1 2 1 0 2 0 0 0
#  0 1 0 2 2 0 0 2 1 0 2 0 0 1 0 2 0 2 0 2 1 0 0 2 1 0 1 2 1 2 2 0 2 0 0 0 1
#  1 0 2 1 1 2 0 0 2 1 2 1 2 0 2 2 2]
